# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Abinay Rachakonda\Downloads\data.xlsx - Sheet1.csv")

# %%
data
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %%
data.shape
# Out:
# (3998, 39)

# %% [markdown]
# # Data Cleaning

# %%
data['Unnamed: 0'].value_counts()
# Out:
# train    3998
# Name: Unnamed: 0, dtype: int64

# %%
data.pop('Unnamed: 0')
# Out:
# 0       train
# 1       train
# 2       train
# 3       train
# 4       train
#         ...
# 3993    train
# 3994    train
# 3995    train
# 3996    train
# 3997    train
# Name: Unnamed: 0, Length: 3998, dtype: object

# %%
data.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
data.shape
# Out:
# (3998, 38)

# %%
data.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
def correct (Target_value="",choice=[],threshold=80):
    match,score = process.extractOne(Target_value,choices)
    if score>=threshold:
        return match
    else:
        return Target_value
Keywords = ['cbsc', 'cbse', 'cbse ', 'cbse board', 'cbse[gulf zone]',
       'central board of secondary education',
       'central board of secondary education, new delhi']
data['10board'] =  data['10board'].replace(Keywords, 'CBSE', regex=True)

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
data['Degree'].value_counts()
# Out:
# B.Tech/B.E.      3700
# MCA               243
# M.Tech./M.E.       53
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
sns.countplot(data=data,x='Degree')
# Out:
# <AxesSubplot:xlabel='Degree', ylabel='count'>

# %%
fig, axs = plt.subplots(1,5, figsize=(10,3), constrained_layout=True)
fig.suptitle("Numerical Feature Visualization with Seaborn")

axs[0].set_title("ElectricalEngg")
sns.kdeplot(data=data, x='ElectricalEngg', ax=axs[0])
axs[1].set_title("ComputerProgramming")
sns.kdeplot(data=data, x='ComputerProgramming', ax=axs[1])

axs[2].set_title("MechanicalEngg")
sns.kdeplot(data=data, x='MechanicalEngg',ax=axs[2])

axs[3].set_title("TelecomEngg")
sns.kdeplot(data=data, x= 'TelecomEngg', ax=axs[3])

axs[4].set_title("CivilEngg")
sns.kdeplot(data=data, x='CivilEngg', ax=axs[4])


plt.show()

# %%
fig, axs = plt.subplots(1,5, figsize=(10,3), constrained_layout=True)
fig.suptitle("Numerical Feature Visualization with Seaborn")

axs[0].set_title("conscientiousness")
sns.kdeplot(data=data, x='conscientiousness', ax=axs[0])

axs[1].set_title("agreeableness")
sns.kdeplot(data=data, x='agreeableness', ax=axs[1])

axs[2].set_title("extraversion")
sns.kdeplot(data=data, x='extraversion',ax=axs[2])

axs[3].set_title("nueroticism")
sns.kdeplot(data=data, x= 'nueroticism', ax=axs[3])

axs[4].set_title("openess_to_experience")
sns.kdeplot(data=data, x='openess_to_experience', ax=axs[4])
# Out:
# <AxesSubplot:title={'center':'openess_to_experience'}, xlabel='openess_to_experience', ylabel='Density'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,3), constrained_layout=True)
fig.suptitle("Numerical Feature Visualization with Seaborn")

axs[0].set_title("10percentage")
sns.kdeplot(data=data, x='10percentage', ax=axs[0])
axs[1].set_title('12percentage')
sns.kdeplot(data=data, x='12percentage', ax=axs[1])
# Out:
# <AxesSubplot:title={'center':'12percentage'}, xlabel='12percentage', ylabel='Density'>

# %%
fig, axs = plt.subplots(1,4, figsize=(10,3), constrained_layout=True)
fig.suptitle("Numerical Feature Visualization with Seaborn")


axs[0].set_title('collegeGPA')
sns.kdeplot(data=data, x='collegeGPA', ax=axs[0])

axs[1].set_title('English')
sns.kdeplot(data=data, x='English', ax=axs[1])

axs[2].set_title('Logical')
sns.kdeplot(data=data, x='Logical', ax=axs[2])

axs[3].set_title('Quant')
sns.kdeplot(data=data, x='Quant', ax=axs[3])

plt.show()

# %%
data['GraduationYear'] = data['GraduationYear'].replace(0,2014)

# %%
data['GraduationYear'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CollegeState'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.JobCity=data["JobCity"].apply(lambda x : x.replace('-1','Not Mentioned') if '-1' in x else x )
data['JobCity'] = data['JobCity'].apply(lambda x : x.upper().strip())

# %%
data.JobCity.value_counts()[:30].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data.Designation.value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x=data.Specialization)
plt.xticks(rotation=90)
plt.show()

# %%
data.Specialization.value_counts()[:10].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data,y='Salary')
# Out:
# <AxesSubplot:ylabel='Salary'>

# %% [markdown]
# # Bivarite analysis

# %%
numerical_column = ['10percentage','12percentage', 'collegeGPA','English', 'Logical', 'Quant','Domain','ComputerProgramming',
                     'ElectronicsAndSemicon','ComputerScience', 'MechanicalEngg',
       'ElectricalEngg', 'TelecomEngg', 'CivilEngg','conscientiousness',
       'agreeableness', 'extraversion', 'nueroticism',
       'openess_to_experience','Salary']

# %%
# Create subplots
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 20))
axes = axes.flatten()  # Flatten the 2D array of axes for easy indexing

# Loop through each numerical column and create KDE plot
for i, column in enumerate(numerical_column):
    sns.histplot(data[column],color='blue', ax=axes[i])
    a=data[data[column]!=-1]
    sns.histplot(a[column],color='red', ax=axes[i])
    axes[i].set_title(f'KDE Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
data.Specialization.unique()
# Out:
# array(['computer engineering',
#        'electronics and communication engineering',
#        'information technology', 'computer science & engineering',
#        'mechanical engineering', 'electronics and electrical engineering',
#        'electronics & telecommunications',
#        'instrumentation and control engineering', 'computer application',
#        'electronics and computer engineering', 'electrical engineering',
#        'applied electronics and instrumentation',
#        'electronics & instrumentation eng',
#        'information science engineering', 'civil engineering',
#        'mechanical and automation', 'industrial & production engineering',
#        'control and instrumentation engineering',
#        'metallurgical engineering',
#        'electronics and instrumentation engineering',
#        'electronics engineering', 'ceramic engineering',
#        'chemical engineering', 'aeronautical engineering', 'other',
# ...

# %%
# Create subplots
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 20))
axes = axes.flatten()  # Flatten the 2D array of axes for easy indexing

# Loop through each numerical column and create KDE plot
for i, column in enumerate(numerical_column):
    sns.kdeplot(data[column],color='blue', ax=axes[i])
    a=data[data[column]!=-1]
    sns.kdeplot(a[column],color='red', ax=axes[i])
    axes[i].set_title(f'KDE Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
data_grouped = data.groupby('Designation')

# %%
data_grouped.first()
# Out:
#                               Unnamed: 0       ID    Salary          DOJ  \
# Designation
# .net developer                     train  1207660  120000.0  4/1/14 0:00
# .net web developer                 train   533998  240000.0  5/1/14 0:00
# account executive                  train   454921  320000.0  8/1/13 0:00
# account manager                    train   669977  350000.0  8/1/13 0:00
# admin assistant                    train  1268410  105000.0  1/1/15 0:00
# ...                                  ...      ...       ...          ...
# web designer and seo               train  1284437  200000.0  1/1/15 0:00
# web developer                      train    30122  100000.0  7/1/11 0:00
# web intern                         train  1193240  205000.0  4/1/14 0:00
# website developer/tester           train   833277  200000.0  9/1/14 0:00
# windows systems administrator      train   455164  200000.0  9/1/12 0:00
#
# ...

# %%
data['Designation'] = data['Designation'].replace('systems engineer','system engineer')

# %%
data_grouped.get_group('software engineer')['GraduationYear'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_grouped.get_group('system engineer')['Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_grouped.get_group('software developer')['Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_grouped.get_group('programmer analyst')['GraduationYear'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_grouped.get_group('java software engineer')['Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_grouped.get_group('software test engineer')['Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
sns.scatterplot(data=data,x='collegeGPA',y='Salary')
# Out:
# <AxesSubplot:xlabel='collegeGPA', ylabel='Salary'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x='Specialization',y='Salary')
plt.xticks(rotation=90)
plt.show()

# %%
data['Degree'].value_counts()
# Out:
# B.Tech/B.E.      3700
# MCA               243
# M.Tech./M.E.       53
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(data=data,x='Degree',y='Salary')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=data,x='English',y='Salary')
# Out:
# <AxesSubplot:xlabel='English', ylabel='Salary'>
